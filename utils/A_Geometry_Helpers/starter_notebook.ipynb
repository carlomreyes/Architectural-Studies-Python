# %% [markdown]
# # A_Geometry_Helpers Starter Notebook
# Examples using geometry_helpers: grid_points and bbox.

# %%
from utils.A_Geometry_Helpers.geometry_helpers import grid_points, bbox
pts = grid_points(3,3)
print('pts:', pts)
print('bbox:', bbox(pts))
