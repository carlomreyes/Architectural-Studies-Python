# %% [markdown]
# # B_Cantilever_Studies Starter Notebook
# Starter for cantilever study examples and small calculations.

# %%
def cantilever_deflection(load, length, E=210e9, I=1e-6):
    return load * length**3 / (3 * E * I)

print('deflection:', cantilever_deflection(500, 1.5))
