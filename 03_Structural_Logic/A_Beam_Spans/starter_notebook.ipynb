# %% [markdown]
# # A_Beam_Spans Starter Notebook
# Beam span example with a simple deflection formula.

# %%
def beam_deflection(load, span, E=210e9, I=1e-6):
    return load * span**3 / (48 * E * I)

print('Sample deflection:', beam_deflection(1000, 2.0))
