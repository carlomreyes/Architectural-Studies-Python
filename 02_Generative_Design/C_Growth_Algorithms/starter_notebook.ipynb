# %% [markdown]
# # C_Growth_Algorithms Starter Notebook
# Starter for growth algorithm experiments (e.g., diffusion-limited aggregation).

# %%
# Simple branching demo
paths = [[(0,0)]]
for step in range(3):
    new = []
    for p in paths:
        new.append(p + [(len(p), 0)])
        new.append(p + [(len(p), 1)])
    paths = new
print('Generated', len(paths), 'paths')
