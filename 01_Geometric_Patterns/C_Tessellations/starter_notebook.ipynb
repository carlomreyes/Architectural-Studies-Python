# %%
from utils.A_Geometry_Helpers.geometry_helpers import grid_points\n
pts = grid_points(4,4, spacing=1.0)\n
print('Grid points sample:', pts[:8])\n
# Next: use these points to build tile centers for tessellation examples\n
