# %% [markdown]
# # D_Voronoi Starter Notebook
# Voronoi starter and notes for using scipy.spatial.Voronoi.

# %%
# Install scipy to run Voronoi examples
print('Voronoi starter: add scipy.spatial.Voronoi example here')
